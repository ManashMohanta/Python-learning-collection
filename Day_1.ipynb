# %%
print("hello world")
# Out:
# hello world

# %% [raw]
# # markdown "Notes, headings, explanations aur documentation likhne ke liye. Ye code execute nahi hota."

# %% [raw]
# # raw"Raw cell me likha hua text **na execute hota hai aur na hi Markdown format hota hai**. Ye plain text hota hai aur bahut kam use hota hai."
# ```text
# This is raw text.
# It will not be formatted or executed.

# %%
print("My name is Manash Ranjan Moahanta")
# Out:
# My name is Manash Ranjan Moahanta
