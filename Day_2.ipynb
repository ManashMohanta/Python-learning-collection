# %%
print("rajiv")
# Out:
# rajiv

# %%
# variables
num=2
num+4
#variables
2num=45
2num+6

# %%
NUMBER=45
type(NUMBER)
# Out:
# int

# %% [markdown]
# num='''rajiv'''
# type(num)

# %%
sentence="this is ravi's house"
sentence
# Out:
# "this is ravi's house"

# %%
#sequencial data type
tuple
list
set
dict
# Out:
# dict

# %%
name="rahul","ravi","rohan"
type(name)
# Out:
# tuple

# %%
t1=("rohit","rani",5,15,245.21)
type(t1)
# Out:
# tuple

# %%
l=["rani","mani",52,52,521,32]
type(l)
# Out:
# list

# %%
s={35,45,7,"rama","ravan"}
type(s)
# Out:
# set

# %%
s={35,45,7,"rama","ravan"}
print(s)
type(s)
# Out:
# {35, 7, 'rama', 45, 'ravan'}
# set

# %%
d={2:"rama",3:"rohit",6:'rani'}
d
type(d)
# Out:
# dict

# %%
#string operation---
s="ravi mahapatra"
#indexing -> slicing
s[5:7]#-> var[starting_index : last_index +1]
print(s[5:14])
# Out:
# mahapatra

# %%
st="ronit pattnaik"
print(st[0:5])
print(st[6:10])
print(st[10:14])
# Out:
# ronit
# patt
# naik

# %%
s="we are here to learn and enjoy"
#"aehr","lan","ejy"
print(s[25:30:2])#var[start_index:last_index+1:step]
print(s[15:20:2])
print(s[3:12:2])
# Out:
# ejy
# lan
# aehr

# %%
#neagative indexing
para="""in this world there are 2 types of people,
one is who carried the pressure and one is who fears the pressure"""
print(para)
#fears"
print("\n",para[-18:-13])
#who
print("\n",para[-22:-19])
#perssure
print("\n",para[-8:])
# Out:
# in this world there are 2 types of people,
# one is who carried the pressure and one is who fears the pressure
#
#  fears
#
#  who
#
#  pressure

# %%
#negative stepping
name="rohit sharma"
#"amrahs
print("\n",name[11:5:-1])
# Out:
#  amrahs

# %%
#take a string "rahul is abgood test player."
r="rahul is a good test player."
#"rahul"
print("\n",r[0:5])
#doog
print("\n",r[14:10:-1])
#test
print("\n",r[16:20])
#ryl st
print("\n",r[26:15:-2])
#si
print("\n",r[7:5:-1])
# Out:
#  rahul
#
#  doog
#
#  test
#
#  ryl st
#
#  si
