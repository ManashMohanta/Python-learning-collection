# %%
#reverse the string
st="crazy brown fox jumps over the lazy dog"
print("\n",st[39::-1])
# Out:
#  god yzal eht revo spmuj xof nworb yzarc

# %%
#string operation
#lower,upper
s="rama is a good boy"
print(s.upper())
# Out:
# RAMA IS A GOOD BOY

# %%
s="RAMA IS A GOOD BOY"
print(s.lower())
# Out:
# rama is a good boy

# %%
#title and capitalize
s="rama is a good boy"
print(s.capitalize())
# Out:
# Rama is a good boy

# %%
s="rama is a good boy"
print(s.title())
# Out:
# Rama Is A Good Boy

# %%
s="rama is a good boy"
s.endswith("y")
# Out:
# True

# %%
s="rama is a good boy"
s.startswith("rama")
# Out:
# True

# %%
s="rama is a good boy"
s.find("good")
# Out:
# 10

# %%
s="rama is a good boy"
s.find("z")
# Out:
# -1

# %%
s="rama is a good boy"
s.index("good")
# Out:
# 10

# %%
num="457"
num.isdigit()
# Out:
# True

# %%
num="45r7"
num.isdigit()
# Out:
# False

# %%
st="r"
st.isalpha()
# Out:
# True

# %%
an="45rajiv"
an.isalnum()
# Out:
# True

# %%
an="45rajiv&"
an.isalnum()
# Out:
# False

# %%
s="we are bears"
s.split()
# Out:
# ['we', 'are', 'bears']

# %%
s="we_are_bears"
s.split("_")
# Out:
# ['we', 'are', 'bears']

# %%
s="rama"
s.center(34,"*")
# Out:
# '***************rama***************'

# %%
s="rama"
s.center(34,"👌")
# Out:
# '👌👌👌👌👌👌👌👌👌👌👌👌👌👌👌rama👌👌👌👌👌👌👌👌👌👌👌👌👌👌👌'

# %%
s="rama is a good boy"
len(s)
# Out:
# 18

# %%
s="        rama is a good boy         "
s.strip()
# Out:
# 'rama is a good boy'

# %%
s="        rama is a good boy         "
after_strip=s.strip()
print(after_strip)
length=len(after_strip)
print(length)
# Out:
# rama is a good boy
# 18

# %%
s="R"
s.isupper()
# Out:
# True

# %%
#indexing in list-> slicing of list
l=[45,56.3,True,"ravi"]
print(l[3])
# Out:
# ravi

# %%
l=[56,67,89,4,4,76,4,37,89,54,89]
#4,4,76,4
print(l[3:7])
# Out:
# [4, 4, 76, 4]

# %%
ls=["rama","ravi","rohit","rajan"]
print(ls[2:])
print(ls[::-1])
# Out:
# ['rohit', 'rajan']
# ['rajan', 'rohit', 'ravi', 'rama']

# %%
ls=["rama","ravi","rohit","rajan"]
#make rohit 's first letter in upper
print(ls[2].capitalize())
# Out:
# Rohit

# %%
#operations in list :
ls=[45,56,78,89]
#add 687 in it
ls.append(687)
print(ls)
# Out:
# [45, 56, 78, 89, 687]

# %%
#operations in list :
ls=[45,56,78,89]
#add 687 in it
ls.append(687)
#add 590 after 56
ls.insert(2,590)
#add 245,679,5768 in it
ls.extend([245,679,5768])
print(ls)
# Out:
# [45, 56, 590, 78, 89, 687, 245, 679, 5768]

# %%
ls=[45,56,78,89]
#remove 89 from it
ls.pop()
#delet 56 from it
ls.pop(1)
#remove 78 from it 
ls.remove(78)
print(ls)
# Out:
# [45]

# %% [markdown]
# ls=[51,32,54,78,48,78,]
# ls.remove(78)
# print(ls)

# %%
ls=[51,32,54,78,48,78,]
ls.remove(78)
print(ls)
# Out:
# [51, 32, 54, 48, 78]

# %%
#nested list
ls=[45,67,78,[56,67,9,90,45,67],[5678,5688]]
ls[3]
# Out:
# [56, 67, 9, 90, 45, 67]

# %%
#nested list
ls=[45,67,78,[56,67,9,90,45,67],[5678,5688]]
ls[3][2]
# Out:
# 9

# %%
#
ls=[45,58,[45,"ravi",[56,79]]]
print(ls[2][1])
print(ls[2][2][0])
ls[2][2].append("rohit")
print(ls)
ls[2][2].remove(79)
print(ls)
# Out:
# ravi
# 56
# [45, 58, [45, 'ravi', [56, 79, 'rohit']]]
# [45, 58, [45, 'ravi', [56, 'rohit']]]

# %%
ls=[45,76,9,654,45,678]
ls.count(45)
# Out:
# 2

# %%
ls=[45,76,9,654,678]
ls.sort()
print(ls)
# Out:
# [9, 45, 76, 654, 678]

# %%
ls=[45,76,9,654,678]
ls.sort(reverse=True)
print(ls)
# Out:
# [678, 654, 76, 45, 9]

# %%
ls=["A","a","b","c","c"]
ls.sort()
print(ls)
# Out:
# ['A', 'a', 'b', 'c', 'c']

# %%
print("A->",ord("A"))
print("A->",ord("Z"))
print("A->",ord("a"))
print("A->",ord("z"))
# Out:
# A-> 65
# A-> 90
# A-> 97
# A-> 122

# %%
chr(5)
# Out:
# '\x05'

# %%
ls=["Ravi","Ayan","Rami","Raghav","mani"]
ls.sort()
print(ls)
# Out:
# ['Ayan', 'Raghav', 'Rami', 'Ravi', 'mani']

# %%
name=input("enter your name over here ->")
print("your name is",name)
print(type(name))

# %%
#type casting
#change of data type from one to another
num="456687"
num=int(num)#int("456687")->456678
type(num)

# %%
name="ravi"
name=set(name)
print(name)

# %%
name="ravi"
name=bool(name)
print(name)

# %%
num=int(input("enter a number"))#"45"-> int("45")
print(type(num))
print(num+4)

# %%
# Take a name frpm user as user input and only show his/her surname

name=input("enter your name over here ->")
print("your surname name is ->",name.split()[-1])

# %%
# Take a list ["ravi mahol","rita mira pradhan","rohan desai"]
#make every name in upercase
#sort and arrange all names
#print "mira" from this list

# %%
names = ["ravi mahol", "rita mira pradhan", "rohan desai"]

names = [names[0].upper(), names[1].upper(), names[2].upper()]
names.sort()

print(names)
print(names[1].split()[1])
