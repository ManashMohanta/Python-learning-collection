# %%
name=str (input("enter your name")).lower().title()
sp=name.split()
print(sp[0]+ sp[1])# + is use to concadinate
# Out:
# enter your name MANASH mohanta
# ManashMohanta

# %%
# operators

# %%
# operator-> operates-> operands

# %%
#Aarithmatic operator

+,-,*,/,//(floor division),%(modules),(23)eg.2 power 3

# %%
# Arithmatic problem
45/5
# Out:
# 9.0

# %%
#asignment operator
 =,+=, -=,*=,/=,//=,**=

# %%
#relational operator
<,>,<=,>=,==,!=

# %%
#logical operator
and , or , not

# %%
#logical problem

38==38 and print("manash")
not 30== 30
# Out:
# manash
# False

# %%
#membership operator
in, not in

# %%
# membership problem
l=["ravi", "nandi"]
"nandi" not in l
# Out:
# False

# %%
# membership problem
l=["ravi", "nandi"]
"nandi"  in l
# Out:
# True

# %%
#identity operator
is , is not

# %%
#identity problem
a= 45
b=45
a is b
# Out:
# True

# %%
#identity problem
a= 450
b=450 # false due to max store 255
a is b
# Out:
# False

# %%
#identity operator
a= 256
b= 256 # false due to ma store 256
a is b
# Out:
# True

# %%
#identity operator
a= 256
b= 256 # false due to ma store 256
a is not b
# Out:
# False

# %%
# problem 
# take a user input for 1 character and cheack it vowel or not 
# take  a user input to check year is leap year or not
 # take a user  input to add digits from a 3digit no.

# %%
v = input("enter character")
v in "aeiouAEIOU" and print("vowel")
# Out:
# enter character y
# False

# %%
## leap year
year= (int(input("year")))
(year % 4==0 and year % 100!= 0) or (year% 400== 0)
# Out:
# year 2024
# True

# %%
## take 3 digit no.
digit=input("enter any three digit no.")
print(int (digit[0])+int (digit[1])+ int(digit[2]))
# Out:
# enter any three digit no. 345
# 12

# %%
#take a user input to add digits from  3 digit number
num= int (input("enter a no."))
sum =0
last= num % 10 # 345 % 10 =5
num//= 10 # 345 // 10= 34
sec =num %10 # 34% 10 =4
num //=10 # 34 // 10 =3
first = num % 10 # 3% 10=3
print ("sum of all digits is ", last +sec+first)
# Out:
# enter a no. 345
# sum of all digits is  12

# %%
# set operation
s={34, 56,78, 89, 54, 54 ,45, 54}# set is a collection of unique value
s.add(68789)
s.add(5)
s # set always set in acending order
# Out:
# {5, 34, 45, 54, 56, 78, 89, 68789}

# %%
s={34, 56,78, 89, 54, 54 ,45, 54}
s.pop()# it remove any no. man marji
s. pop()
s
# Out:
# {45, 56, 78, 89}

# %%
s={34, 56,78, 89, 54, 54 ,45, 54}
s.remove(56)# it remove by value
s.remove(54) # it doesn't remove by index
s
# Out:
# {34, 45, 78, 89}

# %%
s = {34, 56, 78, 89, 34}
s1= {234, 56, 73}
s.union(s1) # one set mai dalna ha no dublicate
# Out:
# {34, 56, 73, 78, 89, 234}

# %%
s.intersection(s1) # check the same no.
# Out:
# {56}

# %%
s.difference(s1)# diff kitna ha s1 se
# Out:
# {34, 78, 89}

# %%
# dict operation 
d= {1:"ravi", 2:"rohit", 3: "rama"}
d. update({4:"rani"})# key check no present then at last
d
# Out:
# {1: 'ravi', 2: 'rohit', 3: 'rama', 4: 'rani'}

# %%
# dict operation 
d= {1:"ravi", 2:"rohit", 3: "rama"}
d. update({2:"rani"}) # key is present then replace
d
# Out:
# {1: 'ravi', 2: 'rani', 3: 'rama'}

# %%
# dict operation 
d= {1:"ravi", 2:"rohit", 3: "rama"}
d[1] # index wise not work by key wise done
# Out:
# 'ravi'

# %%
# dict operation 
d= {1:"ravi", 2:"rohit", 3: "rama"}
d[4]="manash"# add key wise
d
# Out:
# {1: 'ravi', 2: 'rohit', 3: 'rama', 4: 'manash'}

# %%
# dict operation 
d= {1:"ravi", 2:"rohit", 3: "rama"}
d.pop(2)#  delete by key
d
# Out:
# {1: 'ravi', 3: 'rama'}

# %%
# dict operation 
d= {"name":"ravi", "city":"BBSR", "id": "56"}
d.pop("id")# delete  by key (key should be any thing)
d
# Out:
# {'name': 'ravi', 'city': 'BBSR'}

# %%
# dict operation 
d= {"name":"ravi", "city":"BBSR", "id": 56}
d.keys()#
d
# Out:
# {'name': 'ravi', 'city': 'BBSR', 'id': 56}

# %%
# dict operation 
d={"name":"ravi", "city":"BBSR", "id": 56}
d.items()# for sort 
d
# Out:
# {'name': 'ravi', 'city': 'BBSR', 'id': 56}

# %%
# tuple is a im mutable data type 
t= (345,4,56,77)

# %%
#tuple
t= (334,33,44)
t[0]
# Out:
# 334
