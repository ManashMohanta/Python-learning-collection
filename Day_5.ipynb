# %%
# using arithmatic operations
a= 20
b= 5
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a%b)
print(a//b)
# Out:
# 25
# 15
# 100
# 4.0
# 0
# 4

# %%
#  value finding (a+b)*c-a/b%d//e
a=10
b=5
c=15
d=2
e= 3
print((a+b)*c-a/b)
# Out:
# 223.0

# %%
# using assingment operation
a=10
a+=5
a*=2
a-=4
a%=5
print (a)
# Out:
# 1

# %%
#using some relational operation
a= 30
b= 30
print(a>b)
print(a<b)
print(a==b)
print(a!=b)
print(a>=b)
print(a<=b)
# Out:
# False
# False
# True
# False
# True
# True

# %%
#Using relational operations
a=10
b=3
c= 20
print (a>5 and b> 15) # if both are true then true
print (a>15 or c> 15) # if any any one is true then true
print (not(a==b)) # def not equal
# Out:
# False
# True
# True

# %%
# concatenate  to joining strings
s1= "Manash"
s2= "Ranjan"
s3= "Mohanta"
print(s1+" "+s2+" "+ s3)
# Out:
# Manash Ranjan Mohanta

# %%
# repeat a string and  findig length
s ="ERROR"+" "
print (s* 4)
print (len(s*4))
# Out:
# ERROR ERROR ERROR ERROR
# 24

# %%
# slicing  a string
s= "I LIKE TO PLAY VEDIOGAMES"
print(s[:6])
print (s[-10:])
# Out:
# I LIKE
# VEDIOGAMES

# %%
# diff between non reverse and reverse of string 
s= "FAKE LOVE"
print(s[-1:-10:-1])# (string name[ start: end: to reverse (-) is used ]){ by negative sign}
print (s[0:10:1])# (string name[start index: end index: how much skip to for (-)reverse and without any sign no reverse])
# Out:
# EVOL EKAF
# FAKE LOVE

# %%
# print alternate character
s= "Cloud Computering"
print (s[::1])
print(s[::2])
# Out:
# Cloud Computering
# CodCmueig

# %%
# joining to list and finding its length
list1= [10,20,30]
list2=[40,50,60]
list3=list1+list2
print(list3)
print(len(list3))
# Out:
# [10, 20, 30, 40, 50, 60]
# 6

# %%
# to repeat a list 3 time and its length
num=[3,5,8]
print(num*3)
print (len(num*3))
# Out:
# [3, 5, 8, 3, 5, 8, 3, 5, 8]
# 9

# %%
# print first , middle, and last element of list
num=[10,20,30,40,50,60]
print(num[0])
print(num[2 ])
print(num[5])
# Out:
# 10
# 30
# 60

# %%
#reverse a list
num=[5,7,9,8,6]
print(num[::-1])# same as string
# Out:
# [6, 8, 9, 7, 5]

# %%
# finding elements in nestedlist
ele=[[10,20], [30,40], [50,6070,80]]
print(ele[0][1])
print(ele[1][1])
print(ele[2][1])
# Out:
# 20
# 40
# 6070

# %%
# membership operator
ls=[100,300,400,600,1000]
print(600 in ls)
print(1000 not in ls)
# Out:
# True
# False

# %%
#comparing length of two lists
ls1=[1,2,3]
ls2=[4,5,6,7]
print (len(ls1)<len(ls2))
print (len(ls1)>len(ls2))
# Out:
# True
# False

# %%
# finding elements in nestedlist and  add them
ele=[[10,20], [30,40], [50,6070,80]]
print(ele[0][1]+ele[1][1]+ele[2][1])
# Out:
# 6130

# %%
# print second element and last of tuple
t=(100,200,300,400)
print(t[1])
print(t[-1])
# Out:
# 200
# 400

# %%
# NOTE  : 
1.LIST ARE ALWAYS INSIDE SQUARE BRACKET[]
2.SET ARE ALWASYS INSIDE CURLY BRACKET{}
3.TUPLE ARE ALWAYS INSIDE CIRCULAR BRACKET()

# %%
# Union of sets and in sorted
set1={20,30,40,50,60,10}
set2={70,80,90}
print(sorted(set1|set2))
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80, 90]

# %%
# intersection of sets
set1 ={1,3,7,2}
set2={4,5,6,8,2,1}# it find out common element inside both set
print (set1&set2)
# Out:
# {1, 2}

# %%
# difference of set
set1= {20,30,80,50,90}
set2={10, 90,80}
print(set1-set2)
# Out:
# {50, 20, 30}

# %%
#dictionary  values
student={"Name":"Manash","Age":20,"Branch":"CSE","CGPA":9.0}
print(student["Name"])
print(student["Age"])
print(student["Branch"])
print(student["CGPA"])
# Out:
# Manash
# 20
# CSE
# 9.0

# %%
# add new key value pair in dictionary
student={"Name":"Manash","Age":20,"Branch":"CSE"}
student["city"]="Mayurbhanj"
print(student)
# Out:
# {'Name': 'Manash', 'Age': 20, 'Branch': 'CSE', 'city': 'Mayurbhanj'}

# %%
#identity operator
list1=[10,20,30]
list2= list1
list3=[10,20,30]
print(list1 is list2)
print(list1 is not list3)
# Out:
# True
# True
